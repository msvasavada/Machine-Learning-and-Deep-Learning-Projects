# %% [markdown]
# ![sslogo](https://github.com/stratascratch/stratascratch.github.io/raw/master/assets/sslogo.jpg)

# %% [markdown]
# # An Introduction to Pandas

# %% [markdown]
# To edit this notebook:
# - Save the notebook by selecting `Download .ipynb` from the `File` tab
# - Go to [Colaboratory](https://colab.research.google.com/) and upload the notebook from the `File` tab
# - Alternatively, you can import the notebook to your Google Drive and select `Open with` when you right-click. Select `Colaboratory` or `+ Connect more apps` to install Colaboratory first

# %% [markdown]
# ## Basic Pandas Concepts
#
# Some very basic Pandas and python concepts to get started

# %% [markdown]
# #### Import the pandas package

# %%
import pandas as pd

# %% [markdown]
# #### Create a simple DataFrame
#
# - syntax: pd.DataFrame({column1 : value1, column2 : value2, column3: value3})

# %%
df = pd.DataFrame({'name':['Bob','Jen','Tim'],
                   'age':[20,30,40],
                   'pet':['cat', 'dog', 'bird']})

df
# Out:
#    age name   pet
# 0   20  Bob   cat
# 1   30  Jen   dog
# 2   40  Tim  bird

# %% [markdown]
# #### View the column names and index values

# %%
print(df.columns)
print(df.index)
# Out:
# Index(['age', 'name', 'pet'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# #### Select a column by name in 2 different ways

# %%
print(df['name'])
print(df.name)
# Out:
# 0    Bob
# 1    Jen
# 2    Tim
# Name: name, dtype: object
# 0    Bob
# 1    Jen
# 2    Tim
# Name: name, dtype: object

# %% [markdown]
# #### Select multiple columns

# %%
df[['name','pet']]
# Out:
#   name   pet
# 0  Bob   cat
# 1  Jen   dog
# 2  Tim  bird

# %% [markdown]
# #### Select a row by index

# %%
df.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4d410358643a> in <module>()
# ----> 1 df.iloc[0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Sort Function
#
# - pandas.pydata.org
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html

# %% [markdown]
# #### Sort the data by pet

# %%
df.sort_values('pet',inplace=True, ascending=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88d93230f16e> in <module>()
# ----> 1 df.sort_values('pet',inplace=True, ascending=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Indexing with DataFrames
#
# - Row and column are the relative position of the data cells you want
# - To select multiple rows or columns, use a colon to separate the start and end values
# - Colon with no value returns all rows or columns

# %% [markdown]
# #### View the index after the sort

# %%
df
# Out:
#    age name   pet
# 2   40  Tim  bird
# 0   20  Bob   cat
# 1   30  Jen   dog

# %% [markdown]
# #### Difference between loc and iloc

# %%
df.loc[0] #index based
# Out:
# age      20
# name    Bob
# pet     cat
# Name: 0, dtype: object

# %%
df.iloc[0] #relative position based indexing
# Out:
# age       40
# name     Tim
# pet     bird
# Name: 2, dtype: object

# %% [markdown]
# #### Use iloc to select all rows of a column

# %%
df.iloc[:,2]
# Out:
# 2    bird
# 0     cat
# 1     dog
# Name: pet, dtype: object

# %% [markdown]
# #### Use iloc to select the last row

# %%
df.iloc[-1,:]
# Out:
# age      30
# name    Jen
# pet     dog
# Name: 1, dtype: object

# %% [markdown]
# ## Basic Pandas Concept Exercises

# %%
sales = [100,130,119,92,35]
customer_account = ['B100','J101','X102','P103','R104']
city = ['BOS','LA','NYC','SF','CHI']

# %% [markdown]
# #### Create a DataFrame with the data above

# %%
df = pd.DataFrame({'sales':sales, 'customer':customer_account, 
                   'city':city})

# %%
df
# Out:
#   city customer  sales
# 0  BOS     B100    100
# 1   LA     J101    130
# 2  NYC     X102    119
# 3   SF     P103     92
# 4  CHI     R104     35

# %% [markdown]
# #### What is the name of the first column?
#
# Remember: The `df.columns` array holds the column names for the dataframe.

# %%
df.columns[0]
# Out:
# 'city'

# %% [markdown]
# #### Sort the DataFrame by city in descending order (check the documentation for sort)

# %%
df.sort_values('city',ascending=False,inplace=True)
df
# Out:
#   city customer  sales
# 3   SF     P103     92
# 2  NYC     X102    119
# 1   LA     J101    130
# 4  CHI     R104     35
# 0  BOS     B100    100

# %% [markdown]
# #### Which customer is in the last row of the DataFrame?

# %%
df.customer.iloc[-1]
# Out:
# 'B100'

# %% [markdown]
# #### Reorder the columns with customer in the first column
#
# Remember how we did array shuffling using permutations in the numpy lesson.
#
# The logic here is very similar except we now use column names instead of integer indices.
#
# We want the first column to be customer, second to be city and third to be sales.
#
# We must supply all column names as the input to this column selection because if we omit even a single one the resulting dataframe will be incomplete.

# %%
df = df[['customer','city','sales']]
df
# Out:
#   customer city  sales
# 3     P103   SF     92
# 2     X102  NYC    119
# 1     J101   LA    130
# 4     R104  CHI     35
# 0     B100  BOS    100

# %% [markdown]
# # Basic Pandas Functionality
#
# Before we learn about what Pandas can do, we need to first import some data
#
# ## Importing Data
#
# Python allows you to connect to any type of database. To make this easy for newbies, we've create a notebook to help you connect to the Strata Scratch platform and pull data. Use the notebook below to pull data from our database.
#
# [Connect to Strata Scratch with Python](https://colab.research.google.com/drive/1VtywiAAI-ucfTzBa6YDca8k4gfGiEPnn)

# %% [markdown]
# ### Install the Database Module
#
# The code below installs a postgres database module to allow our notebook to connect to the Strata Scratch database

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading https://files.pythonhosted.org/packages/5e/d0/9e2b3ed43001ebed45caf56d5bb9d44ed3ebd68e12b87845bfa7bcd46250/psycopg2-2.7.5-cp36-cp36m-manylinux1_x86_64.whl (2.7MB)
#     100% |████████████████████████████████| 2.7MB 9.6MB/s
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.7.5

# %% [markdown]
# ### Import Required Modules
#
# Import a few required modules that enables us to query data and perform analytics

# %%
import numpy as np
import pandas as pd
import psycopg2 as ps
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ### Connect to Strata Scratch
#
# Make sure to enter your username and database password. Your database password is not the same as your login password. You can find your database password in the Profile tab once logged into Strata Scratch.

# %%
host_name = 'db-strata.stratascratch.com'
dbname = 'db_strata'
port = '5432'
user_name = '' #enter username
pwd = '' #enter your database password found in the profile tab in Strata Scratch

try:
    conn = ps.connect(host=host_name,database=dbname,user=user_name,password=pwd,port=port)
except ps.OperationalError as e:
    raise e
else:
    print('Connected!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2a2be5c6e876> in <module>()
#       7 try:
# ----> 8     conn = ps.connect(host=host_name,database=dbname,user=user_name,password=pwd,port=port)
#       9 except ps.OperationalError as e:
#
# NameError: name 'ps' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2a2be5c6e876> in <module>()
#       7 try:
#       8     conn = ps.connect(host=host_name,database=dbname,user=user_name,password=pwd,port=port)
# ----> 9 except ps.OperationalError as e:
#      10     raise e
#      11 else:
#
# NameError: name 'ps' is not defined

# %% [markdown]
# ### Pull the Titanic Dataset From Strata Scratch

# %% [markdown]
# #### Enter SQL code below to pull the dataset you're interested in
#
# If you get an error, it likely means that the connection timed out. Try connecting to Strata Scratch again before executing the code below.
#
# A list of datasets is found in SQL LAB in Strata Scratch.

# %%
#Write SQL below to pull datasets 
cur = conn.cursor()
cur.execute(""" 
            SELECT *  FROM titanic; 
            """)
data = cur.fetchall()
colnames = [desc[0] for desc in cur.description] 
conn.commit()

#create the pandas dataframe
data = pd.DataFrame(data)
data.columns = colnames

#close the connection
cur.close()

# %% [markdown]
# #### Check To See If Your Pulled The Dataset
#
# The Titanic dataset should be in a pandas dataframe named `data`

# %%
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %% [markdown]
# ## Basic Pandas Functionality
#
# Now that we imported some data, let's take a look at what Pandas can do

# %% [markdown]
# #### Investigate the first few rows of data

# %%
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %% [markdown]
# #### Investigate the last 10 rows of data

# %%
data.tail(10)
# Out:
#      passengerid  survived  pclass                                      name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# 881    male    33      0      0            349257   7.8958  None        S
# 882  female    22      0      0              7552  10.5167  None        S
# 883    male    28      0      0  C.A./SOTON 34068  10.5000  None        S
# 884    male    25      0      0   SOTON/OQ 392076   7.0500  None        S
# 885  female    39      0      5            382652  29.1250  None        Q
# 886    male    27      0      0            211536  13.0000  None        S
# 887  female    19      0      0            112053  30.0000   B42        S
# 888  female  None      1      2        W./C. 6607  23.4500  None        S
# 889    male    26      0      0            111369  30.0000  C148        C
# 890    male    32      0      0            370376   7.7500  None        Q

# %% [markdown]
# #### Investigate the data types in the DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# passengerid    891 non-null int64
# survived       891 non-null int64
# pclass         891 non-null int64
# name           891 non-null object
# sex            891 non-null object
# age            714 non-null object
# sibsp          891 non-null int64
# parch          891 non-null int64
# ticket         891 non-null object
# fare           891 non-null float64
# cabin          204 non-null object
# embarked       889 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.6+ KB

# %% [markdown]
# #### Get some summary statistics

# %%
data.describe().T

# %% [markdown]
# ### Filtering Dataframes
#
# You can filter data based on the columns and values in the dataframe

# %% [markdown]
# #### Filter the data for men

# %%
data[data.sex=='male']
# Out:
#      passengerid  survived  pclass                                     name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# 23            24         1       1             Sloper, Mr. William Thompson
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 29            30         0       3                      Todoroff, Mr. Lalio
# 30            31         0       1                 Uruchurtu, Don. Manuel E
# 33            34         0       2                    Wheadon, Mr. Edward H
# 34            35         0       1                  Meyer, Mr. Edgar Joseph
# 35            36         0       1           Holverson, Mr. Alexander Oskar
# 36            37         1       3                         Mamee, Mr. Hanna
# 37            38         0       3                 Cann, Mr. Ernest Charles
# 42            43         0       3                      Kraeff, Mr. Theodor
# 45            46         0       3                 Rogers, Mr. William John
# 46            47         0       3                        Lennon, Mr. Denis
# 48            49         0       3                      Samaan, Mr. Youssef
# 50            51         0       3               Panula, Master. Juha Niilo
# 51            52         0       3             Nosworthy, Mr. Richard Cater
# 54            55         0       1           Ostby, Mr. Engelhart Cornelius
# 55            56         1       1                        Woolner, Mr. Hugh
# 57            58         0       3                      Novel, Mr. Mansouer
# ..           ...       ...     ...                                      ...
# 840          841         0       3              Alhomaki, Mr. Ilmari Rudolf
# 841          842         0       2                 Mudd, Mr. Thomas Charles
# 843          844         0       3               Lemberopolous, Mr. Peter L
# 844          845         0       3                      Culumovic, Mr. Jeso
# 845          846         0       3                      Abbing, Mr. Anthony
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 847          848         0       3                       Markoff, Mr. Marin
# 848          849         0       2                        Harper, Rev. John
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 857          858         1       1                   Daly, Mr. Peter Denis
# 859          860         0       3                         Razi, Mr. Raihed
# 860          861         0       3                  Hansen, Mr. Claus Peter
# 861          862         0       2              Giles, Mr. Frederick Edward
# 864          865         0       2                   Gill, Mr. John William
# 867          868         0       1     Roebling, Mr. Washington Augustus II
# 868          869         0       3              van Melkebeke, Mr. Philemon
# 869          870         1       3          Johnson, Master. Harold Theodor
# 870          871         0       3                        Balkic, Mr. Cerin
# 872          873         0       1                 Carlsson, Mr. Frans Olof
# 873          874         0       3              Vander Cruyssen, Mr. Victor
# 876          877         0       3            Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                     Petroff, Mr. Nedelio
# 878          879         0       3                       Laleff, Mr. Kristo
# 881          882         0       3                       Markun, Mr. Johann
# 883          884         0       2            Banfield, Mr. Frederick James
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 886          887         0       2                    Montvila, Rev. Juozas
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#       sex   age  sibsp  parch            ticket      fare        cabin  \
# 0    male    22      1      0         A/5 21171    7.2500         None
# 4    male    35      0      0            373450    8.0500         None
# 5    male  None      0      0            330877    8.4583         None
# 6    male    54      0      0             17463   51.8625          E46
# 7    male     2      3      1            349909   21.0750         None
# 12   male    20      0      0         A/5. 2151    8.0500         None
# 13   male    39      1      5            347082   31.2750         None
# 16   male     2      4      1            382652   29.1250         None
# 17   male  None      0      0            244373   13.0000         None
# 20   male    35      0      0            239865   26.0000         None
# 21   male    34      0      0            248698   13.0000          D56
# 23   male    28      0      0            113788   35.5000           A6
# 26   male  None      0      0              2631    7.2250         None
# 27   male    19      3      2             19950  263.0000  C23 C25 C27
# 29   male  None      0      0            349216    7.8958         None
# 30   male    40      0      0          PC 17601   27.7208         None
# 33   male    66      0      0        C.A. 24579   10.5000         None
# 34   male    28      1      0          PC 17604   82.1708         None
# 35   male    42      1      0            113789   52.0000         None
# 36   male  None      0      0              2677    7.2292         None
# 37   male    21      0      0        A./5. 2152    8.0500         None
# 42   male  None      0      0            349253    7.8958         None
# 45   male  None      0      0   S.C./A.4. 23567    8.0500         None
# 46   male  None      1      0            370371   15.5000         None
# 48   male  None      2      0              2662   21.6792         None
# 50   male     7      4      1           3101295   39.6875         None
# 51   male    21      0      0        A/4. 39886    7.8000         None
# 54   male    65      0      1            113509   61.9792          B30
# 55   male  None      0      0             19947   35.5000          C52
# 57   male  28.5      0      0              2697    7.2292         None
# ..    ...   ...    ...    ...               ...       ...          ...
# 840  male    20      0      0  SOTON/O2 3101287    7.9250         None
# 841  male    16      0      0       S.O./P.P. 3   10.5000         None
# 843  male  34.5      0      0              2683    6.4375         None
# 844  male    17      0      0            315090    8.6625         None
# 845  male    42      0      0         C.A. 5547    7.5500         None
# 846  male  None      8      2          CA. 2343   69.5500         None
# 847  male    35      0      0            349213    7.8958         None
# 848  male    28      0      1            248727   33.0000         None
# 850  male     4      4      2            347082   31.2750         None
# 851  male    74      0      0            347060    7.7750         None
# 857  male    51      0      0            113055   26.5500          E17
# 859  male  None      0      0              2629    7.2292         None
# 860  male    41      2      0            350026   14.1083         None
# 861  male    21      1      0             28134   11.5000         None
# 864  male    24      0      0            233866   13.0000         None
# 867  male    31      0      0          PC 17590   50.4958          A24
# 868  male  None      0      0            345777    9.5000         None
# 869  male     4      1      1            347742   11.1333         None
# 870  male    26      0      0            349248    7.8958         None
# 872  male    33      0      0               695    5.0000  B51 B53 B55
# 873  male    47      0      0            345765    9.0000         None
# 876  male    20      0      0              7534    9.8458         None
# 877  male    19      0      0            349212    7.8958         None
# 878  male  None      0      0            349217    7.8958         None
# 881  male    33      0      0            349257    7.8958         None
# 883  male    28      0      0  C.A./SOTON 34068   10.5000         None
# 884  male    25      0      0   SOTON/OQ 392076    7.0500         None
# 886  male    27      0      0            211536   13.0000         None
# 889  male    26      0      0            111369   30.0000         C148
# 890  male    32      0      0            370376    7.7500         None
#
#     embarked
# 0          S
# 4          S
# 5          Q
# 6          S
# 7          S
# 12         S
# 13         S
# 16         Q
# 17         S
# 20         S
# 21         S
# 23         S
# 26         C
# 27         S
# 29         S
# 30         C
# 33         S
# 34         C
# 35         S
# 36         C
# 37         S
# 42         C
# 45         S
# 46         Q
# 48         C
# 50         S
# 51         S
# 54         C
# 55         S
# 57         C
# ..       ...
# 840        S
# 841        S
# 843        C
# 844        S
# 845        S
# 846        S
# 847        C
# 848        S
# 850        S
# 851        S
# 857        S
# 859        C
# 860        S
# 861        S
# 864        S
# 867        S
# 868        S
# 869        S
# 870        S
# 872        S
# 873        S
# 876        S
# 877        S
# 878        S
# 881        S
# 883        S
# 884        S
# 886        S
# 889        C
# 890        Q
#
# [577 rows x 12 columns]

# %% [markdown]
# #### Filter the ages for the men

# %%
data.age[data.sex=='male']
# Out:
# 0        22
# 4        35
# 5      None
# 6        54
# 7         2
# 12       20
# 13       39
# 16        2
# 17     None
# 20       35
# 21       34
# 23       28
# 26     None
# 27       19
# 29     None
# 30       40
# 33       66
# 34       28
# 35       42
# 36     None
# 37       21
# 42     None
# 45     None
# 46     None
# 48     None
# 50        7
# 51       21
# 54       65
# 55     None
# 57     28.5
#        ...
# 840      20
# 841      16
# 843    34.5
# 844      17
# 845      42
# 846    None
# 847      35
# 848      28
# 850       4
# 851      74
# 857      51
# 859    None
# 860      41
# 861      21
# 864      24
# 867      31
# 868    None
# 869       4
# 870      26
# 872      33
# 873      47
# 876      20
# 877      19
# 878    None
# 881      33
# 883      28
# 884      25
# 886      27
# 889      26
# 890      32
# Name: age, Length: 577, dtype: object

# %% [markdown]
# ### Adding methods to filters
#
# A method is a function and is used frequently when analyzing data in Pandas. There are countless Pandas methods. We'll go over a few of the basic ones to show how you can use methods to quickly analyze your data.

# %% [markdown]
# #### How many men and women were on the Titanic?

# %%
data.sex[data.sex=='male'].count()
# Out:
# 577

# %%
data.sex[data.sex=='female'].count()
# Out:
# 314

# %% [markdown]
# #### What was the survival rate for adult men (age>=18)

# %%
data.survived[(data.sex=='male')&(data.age>=18)].mean()
# Out:
# 0.17721518987341772

# %% [markdown]
# #### What was the survival rate for women and children?

# %%
data.survived[(data.sex=='female')|(data.age<18)].mean()
# Out:
# 0.6881720430107527

# %% [markdown]
# #### Use groupby to compare the survival rates of men and women

# %%
data.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %% [markdown]
# #### Create a DataFrame with groupby

# %%
new = data.groupby(['sex','pclass'])['survived','age'].mean()
new
# Out:
#                survived
# sex    pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %% [markdown]
# ## Importing and Exporting Data with Pandas
#
# #### Pandas has easy to use functions for importing and exporting different data types:
# - CSV Files
# - Excel Worksheets
# - Queries from Databases
#
# Strata Scratch notebooks will exclusively be import data from our platform so we will not be covering other import techniques.

# %% [markdown]
# ## More Basic Pandas Exercises

# %% [markdown]
# #### What was the average age of the survivors?
#
# In our dataset survirors are labeled with 1 in the `survived` column.
#
# To get all survivors we need the predicate `data.survived==1`.
#
# Once we have the survived rows we take the age column and calculate the mean.

# %%
data.age[data.survived==1].mean()
# Out:
# 28.343689655172415

# %% [markdown]
# #### What was the combined survival rate of both children (age less than 18) and seniors (age greater than 60)?
#
# We have two predicates which we combine using | and then take the mean of the values in survived columns.

# %%
data.survived[(data.age<18)|(data.age>=60)].mean()
# Out:
# 0.4892086330935252

# %% [markdown]
# #### Group by pClass and investigate average survival rate, age and fare

# %%
data.groupby('pclass')['age','survived','fare'].mean()
# Out:
#         survived       fare
# pclass
# 1       0.629630  84.154687
# 2       0.472826  20.662183
# 3       0.242363  13.675550

# %% [markdown]
# #### Create a CSV with the names and ages of the surivors and another CSV file with the names and ages of the deceased. Please refer to documention (to_csv method) to complete the exercise.
#
# `data[['name','age']][data.survived==1]` demonstrates both column selection (taking values for only columns 'name' and 'age') and row selection by a predicate (all who survived)
#
# `.to_csv` just writes the data to disk in a CSV format.
#
# Interestingly the code will work if you invert the order, that is first select rows and then columns. Try it.

# %%
survived = data[['name','age']][data.survived==1]
survived.to_csv('survived.csv')

deceased = data[['name','age']][data.survived==0]
deceased.to_csv('deceased.csv')
